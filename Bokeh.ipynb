# %%
Topics
- creating scatter , line , plot in bokeh
- parameters(color , title , xaxis, yaxis, legend, size)

# %%
import bokeh
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers
output_file('test.html')
p = figure(title = "test flower")
p.xaxis.axis_label = "petal length"        
p.yaxis.axis_label = "petal width"
p.circle(flowers["petal_length"], flowers["petal_width"])
show(p)
# Out:
#   <div class="bk-root" id="be09b9c3-70e6-4963-849e-24773f60b6c1" data-root-id="1404"></div>

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers
output_file('line.html')
a = [2,3,4,5,6,7]
b = [2,5,6,7,8,9]
p = figure(title = "line plot")
p.xaxis.axis_label = "x axis"        
p.yaxis.axis_label = "y axis"
p.line(a,b)
show(p)
# Out:
#   <div class="bk-root" id="86929729-6da5-4df9-9d80-21698da0d1c5" data-root-id="1687"></div>

# %%
p = figure(title = "scatter plot")
p.xaxis.axis_label = "x axis"        
p.yaxis.axis_label = "y axis"
p.scatter(a,b, fill_color = "red",legend_label = "red points",size = 50)
show(p)
# Out:
#   <div class="bk-root" id="e7d97dc1-2428-4506-bf1a-0c45827d26dd" data-root-id="3134"></div>
